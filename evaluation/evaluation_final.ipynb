# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define evaluation functions

def MAPE(v, v_, axis=None):
    mask = v != 0  # Ignore samples where true value is 0
    if np.any(mask):
        mape = (np.abs(v_[mask] - v[mask]) / np.abs(v[mask])).astype(np.float64)
        mape = np.where(mape > 5, 5, mape)
        return np.mean(mape, axis)
    else:
        return np.nan  # Or some default if all are zero

def RMSE(v, v_, axis=None):
    return np.sqrt(np.mean((v_ - v) ** 2, axis)).astype(np.float64)

def MAE(v, v_, axis=None):
    return np.mean(np.abs(v_ - v), axis).astype(np.float64)

# %%
# Auto-evaluate methods with automatic P/H/offset alignment
import numpy as np, pandas as pd

# Load original raw data (drop header row of IDs)
valid_raw = pd.read_csv('../processed data/yilong/confirmed_state_valid.csv').values
test_raw  = pd.read_csv('../processed data/yilong/confirmed_state_test.csv').values


# Function to find best P, H, offset by minimizing MSE between method GT and original
def find_best_alignment(gt_csv_path, raw_array, P_range=range(1,15), H_range=range(1,15), offset_range=range(-30,30)):
    gt = np.loadtxt(gt_csv_path, delimiter=',')
    num_samples = gt.shape[0]
    seq_len = raw_array.shape[0]
    best_mse = float('inf')
    best_P, best_H, best_offset = None, None, None
    for P in P_range:
        for H in H_range:
            N_eff = num_samples + P + H - 1
            if N_eff > seq_len:
                continue
            for offset in offset_range:
                indices = P + np.arange(num_samples) + offset
                indices = np.clip(indices, 0, seq_len - 1)
                orig = raw_array[indices]
                mse = np.mean((gt - orig)**2)
                if mse < best_mse:
                    best_mse = mse
                    best_P = P
                    best_H = H
                    best_offset = offset
    return best_P, best_H, best_offset, best_mse

# Methods to evaluate (add more if they have GT CSVs)
methods = ['stemgnn_r','stemgnn','stemgnn_w', 'mtgnn','mtgnn_w', 'last_day', 'moving_average']
# methods = ['stemgnn','stemgnn_w', 'mtgnn','mtgnn_w', 'baseline']
# methods = ['stemgnn']

for method in methods:
    print(f"\nEvaluating {method.upper()}...")
    
    # Define GT CSV path for alignment (use step1 for multi-step methods)
    if method == 'mtgnn':
        gt_path_val = '../../baselines_imputation/MTGNN/predictions/daily/val_step_1_ground_truth.csv'
        gt_path_test = '../../baselines_imputation/MTGNN/predictions/daily/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
        pred_dir_val = '../../baselines_imputation/MTGNN/predictions/daily/val_step_{}_predictions.csv'
        pred_dir_test = '../../baselines_imputation/MTGNN/predictions/daily/test_step_{}_predictions.csv'
    elif method == 'mtgnn_w':
        gt_path_val = '../../baselines_imputation/MTGNN/predictions/daily_W/val_step_1_ground_truth.csv'
        gt_path_test = '../../baselines_imputation/MTGNN/predictions/daily_W/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
        pred_dir_val = '../../baselines_imputation/MTGNN/predictions/daily_W/val_step_{}_predictions.csv'
        pred_dir_test = '../../baselines_imputation/MTGNN/predictions/daily_W/test_step_{}_predictions.csv'
    elif method == 'stemgnn':
        gt_path_val = '../../baselines_imputation/StemGNN/output/confirmed_state/train/val_step_1_ground_truth.csv'
        gt_path_test = '../../baselines_imputation/StemGNN/output/confirmed_state/test/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
        pred_dir_val = '../../baselines_imputation/StemGNN/output/confirmed_state/train/val_step_{}_predictions.csv'
        pred_dir_test = '../../baselines_imputation/StemGNN/output/confirmed_state/test/test_step_{}_predictions.csv'
    elif method == 'stemgnn_w':
        gt_path_val = '../../baselines_imputation/StemGNN/output/confirmed_state_w/train/val_step_1_ground_truth.csv'
        gt_path_test = '../../baselines_imputation/StemGNN/output/confirmed_state_w/test/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
        pred_dir_val = '../../baselines_imputation/StemGNN/output/confirmed_state_w/train/val_step_{}_predictions.csv'
        pred_dir_test = '../../baselines_imputation/StemGNN/output/confirmed_state_w/test/test_step_{}_predictions.csv'
    elif method == 'stemgnn_r':
        # STAT-461-Group-Project/StemGNN_modified_data
        gt_path_val = '../StemGNN_modified_data/daily/confirmed_state/train/target_step_0.csv'
        gt_path_test = '../StemGNN_modified_data/daily/confirmed_state/train/target_step_0.csv'
        is_multi_step = True
        steps = 7
        pred_dir_val = '../StemGNN_modified_data/daily/confirmed_state/train/predict_step_{}.csv'
        pred_dir_test = '../StemGNN_modified_data/daily/confirmed_state/test/predict_step_{}.csv'
    elif method == 'last_day':
        # Baseline uses raw data directly, no GT CSV, use step1 GT as reference for alignment
        gt_path_val = '../../baselines_imputation/MTGNN/predictions/daily/val_step_1_ground_truth.csv'  # Use MTGNN step1 GT for alignment
        gt_path_test = '../../baselines_imputation/MTGNN/predictions/daily/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
        # No pred_dir, use raw directly
    elif method == 'moving_average':
        gt_path_val = '../../baselines_imputation/MTGNN/predictions/daily/val_step_1_ground_truth.csv'
        gt_path_test = '../../baselines_imputation/MTGNN/predictions/daily/test_step_1_ground_truth.csv'
        is_multi_step = True
        steps = 7
    else:
        # For single-step methods like stemgnn
        gt_path_val = f'../../baselines_imputation/{method.upper()}/predictions/daily/val_ground_truth.csv'
        gt_path_test = f'../../baselines_imputation/{method.upper()}/predictions/daily/test_ground_truth.csv'
        is_multi_step = False
        steps = 1
        pred_dir_val = f'../../baselines_imputation/{method.upper()}/predictions/daily/val_predictions.csv'
        pred_dir_test = f'../../baselines_imputation/{method.upper()}/predictions/daily/test_predictions.csv'
    
    # Find best alignment for val and test (use val for selection)
    best_P, best_H, best_offset, best_mse = find_best_alignment(gt_path_val, valid_raw)
    print(f"Best alignment: P={best_P}, H={best_H}, offset={best_offset}, MSE={best_mse:.2f}")

    # Now evaluate with best params
    if is_multi_step:
        for k in range(1, steps+1):
            try:
                if method == 'last_day':
                    # For baseline, pred is raw shifted by k days
                    pred_val = valid_raw[:-k]  # Use t-k to predict t
                    orig_val_full = valid_raw[k:]  # Target is t
                    min_len_val = min(len(pred_val), len(orig_val_full))
                    pred_val = pred_val[:min_len_val]
                    orig_val = orig_val_full[:min_len_val]
                    
                    pred_test = test_raw[:-k]
                    orig_test_full = test_raw[k:]
                    min_len_test = min(len(pred_test), len(orig_test_full))
                    pred_test = pred_test[:min_len_test]
                    orig_test = orig_test_full[:min_len_test]
                elif method == 'moving_average':
                    pred_val = np.zeros_like(valid_raw[k:])
                    for i in range(len(pred_val)):
                        start = max(0, k + i - 7)
                        end = k + i
                        pred_val[i] = np.mean(valid_raw[start:end], axis=0)
                    orig_val = valid_raw[k:]
                    pred_test = np.zeros_like(test_raw[k:])
                    for i in range(len(pred_test)):
                        start = max(0, k + i - 7)
                        end = k + i
                        pred_test[i] = np.mean(test_raw[start:end], axis=0)
                    orig_test = test_raw[k:]
                else:
                    if method == 'stemgnn_r':
                        pred_val = np.loadtxt(pred_dir_val.format(k-1), delimiter=',')
                        pred_test = np.loadtxt(pred_dir_test.format(k-1), delimiter=',')
                    else:
                        pred_val = np.loadtxt(pred_dir_val.format(k), delimiter=',')
                        pred_test = np.loadtxt(pred_dir_test.format(k), delimiter=',')
                    
                    # Align original targets
                    L_val = pred_val.shape[0]
                    L_test = pred_test.shape[0]
                    indices_val = best_P + np.arange(L_val) + (k - 1) + best_offset
                    indices_val = np.clip(indices_val, 0, valid_raw.shape[0] - 1)
                    orig_val = valid_raw[indices_val]
                    
                    indices_test = best_P + np.arange(L_test) + (k - 1) + best_offset
                    indices_test = np.clip(indices_test, 0, test_raw.shape[0] - 1)
                    orig_test = test_raw[indices_test]
                
                # Metrics
                mape_val = MAPE(orig_val, pred_val)
                rmse_val = RMSE(orig_val, pred_val)
                mae_val = MAE(orig_val, pred_val)
                mape_test = MAPE(orig_test, pred_test)
                rmse_test = RMSE(orig_test, pred_test)
                mae_test = MAE(orig_test, pred_test)
                
                print(f"Step {k} | Valid MAPE {mape_val:.4f} RMSE {rmse_val:.2f} MAE {mae_val:.2f} | Test MAPE {mape_test:.4f} RMSE {rmse_test:.2f} MAE {mae_test:.2f}")
            except Exception as e:
                print(f"Error evaluating {method} step {k}: {e}")
    else:
        # Single-step evaluation
        pass
        # try:
        #     pred_val = np.loadtxt(pred_dir_val, delimiter=',')
        #     pred_test = np.loadtxt(pred_dir_test, delimiter=',')
            
        #     L_val = pred_val.shape[0]
        #     L_test = pred_test.shape[0]
        #     indices_val = best_P + np.arange(L_val) + best_offset
        #     indices_val = np.clip(indices_val, 0, valid_raw.shape[0] - 1)
        #     orig_val = valid_raw[indices_val]
            
        #     indices_test = best_P + np.arange(L_test) + best_offset
        #     indices_test = np.clip(indices_test, 0, test_raw.shape[0] - 1)
        #     orig_test = test_raw[indices_test]
            
        #     mape_val = MAPE(orig_val, pred_val)
        #     rmse_val = RMSE(orig_val, pred_val)
        #     mae_val = MAE(orig_val, pred_val)
        #     mape_test = MAPE(orig_test, pred_test)
        #     rmse_test = RMSE(orig_test, pred_test)
        #     mae_test = MAE(orig_test, pred_test)
            
        #     print(f"Valid MAPE {mape_val:.4f} RMSE {rmse_val:.2f} MAE {mae_val:.2f} | Test MAPE {mape_test:.4f} RMSE {rmse_test:.2f} MAE {mae_test:.2f}")
        # except Exception as e:
        #     print(f"Error evaluating {method}: {e}")
# Out:
# Evaluating STEMGNN_R...
# Best alignment: P=1, H=1, offset=11, MSE=0.00
# Step 1 | Valid MAPE 1.0960 RMSE 4112.18 MAE 2188.37 | Test MAPE 1.4584 RMSE 3634.50 MAE 2121.67
# Step 2 | Valid MAPE 1.2571 RMSE 4548.77 MAE 2706.63 | Test MAPE 1.7018 RMSE 4229.53 MAE 2649.14
# Step 3 | Valid MAPE 0.9884 RMSE 3848.37 MAE 1991.27 | Test MAPE 1.2760 RMSE 3496.77 MAE 1851.14
# Step 4 | Valid MAPE 0.9352 RMSE 3994.53 MAE 1808.93 | Test MAPE 1.0568 RMSE 3309.49 MAE 1465.37
# Step 5 | Valid MAPE 0.9791 RMSE 3847.60 MAE 1853.92 | Test MAPE 1.1516 RMSE 3432.45 MAE 1654.35
# Step 6 | Valid MAPE 1.3509 RMSE 4179.75 MAE 2497.52 | Test MAPE 1.8414 RMSE 4630.62 MAE 2962.36
# Step 7 | Valid MAPE 1.2439 RMSE 4102.13 MAE 2302.36 | Test MAPE 1.5832 RMSE 4133.28 MAE 2496.03
#
# Evaluating STEMGNN...
# Best alignment: P=1, H=1, offset=11, MSE=0.00
# Step 1 | Valid MAPE 0.9516 RMSE 3986.33 MAE 2106.12 | Test MAPE 1.0676 RMSE 2930.82 MAE 1405.92
# Step 2 | Valid MAPE 1.2755 RMSE 4359.67 MAE 2564.52 | Test MAPE 1.8843 RMSE 4513.43 MAE 2914.68
# Step 3 | Valid MAPE 1.2843 RMSE 4420.80 MAE 2587.00 | Test MAPE 1.6147 RMSE 4054.01 MAE 2464.33
# Step 4 | Valid MAPE 1.4421 RMSE 4965.82 MAE 3052.76 | Test MAPE 1.9031 RMSE 4722.15 MAE 3013.20
# Step 5 | Valid MAPE 1.1324 RMSE 4008.22 MAE 2362.69 | Test MAPE 1.5162 RMSE 3862.28 MAE 2286.82
# Step 6 | Valid MAPE 1.3076 RMSE 4351.45 MAE 2538.59 | Test MAPE 1.7747 RMSE 4419.07 MAE 2773.10
# Step 7 | Valid MAPE 1.1469 RMSE 4129.71 MAE 2317.08 | Test MAPE 1.3762 RMSE 3639.32 MAE 2057.77
#
# Evaluating STEMGNN_W...
# Best alignment: P=1, H=1, offset=11, MSE=0.00
# Step 1 | Valid MAPE 0.9811 RMSE 3915.52 MAE 2078.06 | Test MAPE 1.0776 RMSE 2937.09 MAE 1427.40
# Step 2 | Valid MAPE 1.3707 RMSE 4951.83 MAE 2955.41 | Test MAPE 1.8844 RMSE 4526.22 MAE 2916.38
# Step 3 | Valid MAPE 1.2477 RMSE 4340.57 MAE 2419.02 | Test MAPE 1.5896 RMSE 3977.99 MAE 2407.73
# Step 4 | Valid MAPE 1.4416 RMSE 5465.78 MAE 3189.14 | Test MAPE 1.8996 RMSE 4734.25 MAE 3010.59
# Step 5 | Valid MAPE 1.1635 RMSE 5018.84 MAE 2644.42 | Test MAPE 1.5347 RMSE 3883.43 MAE 2323.46
# Step 6 | Valid MAPE 1.3644 RMSE 4642.37 MAE 2725.88 | Test MAPE 1.7685 RMSE 4410.45 MAE 2761.42
# Step 7 | Valid MAPE 1.0615 RMSE 3957.23 MAE 1984.37 | Test MAPE 1.3735 RMSE 3627.88 MAE 2048.21
#
# Evaluating MTGNN...
# Best alignment: P=1, H=1, offset=12, MSE=0.00
# Step 1 | Valid MAPE 0.7051 RMSE 2888.09 MAE 1333.28 | Test MAPE 0.7657 RMSE 2644.75 MAE 1013.45
# Step 2 | Valid MAPE 1.9424 RMSE 4625.09 MAE 2757.12 | Test MAPE 2.2407 RMSE 3564.70 MAE 2545.51
# Step 3 | Valid MAPE 1.9424 RMSE 4618.79 MAE 2755.76 | Test MAPE 2.2425 RMSE 3831.36 MAE 2580.17
# Step 4 | Valid MAPE 1.9473 RMSE 4579.18 MAE 2750.92 | Test MAPE 2.2389 RMSE 3815.54 MAE 2572.93
# Step 5 | Valid MAPE 1.9577 RMSE 4577.56 MAE 2748.22 | Test MAPE 2.2324 RMSE 3795.81 MAE 2571.45
# Step 6 | Valid MAPE 1.9607 RMSE 4579.18 MAE 2746.93 | Test MAPE 2.2280 RMSE 3795.63 MAE 2571.03
# Step 7 | Valid MAPE 1.9742 RMSE 4577.12 MAE 2744.39 | Test MAPE 2.2311 RMSE 3795.66 MAE 2571.54
#
# Evaluating MTGNN_W...
# Best alignment: P=1, H=1, offset=12, MSE=0.00
# Step 1 | Valid MAPE 0.6772 RMSE 2798.82 MAE 1335.88 | Test MAPE 0.7510 RMSE 2645.99 MAE 1032.45
# Step 2 | Valid MAPE 1.9424 RMSE 4625.09 MAE 2757.12 | Test MAPE 2.2407 RMSE 3564.70 MAE 2545.51
# Step 3 | Valid MAPE 1.9424 RMSE 4618.79 MAE 2755.76 | Test MAPE 2.2425 RMSE 3831.36 MAE 2580.17
# Step 4 | Valid MAPE 1.9473 RMSE 4579.18 MAE 2750.92 | Test MAPE 2.2389 RMSE 3815.54 MAE 2572.93
# Step 5 | Valid MAPE 1.9577 RMSE 4577.56 MAE 2748.22 | Test MAPE 2.2324 RMSE 3795.81 MAE 2571.45
# Step 6 | Valid MAPE 1.9607 RMSE 4579.18 MAE 2746.93 | Test MAPE 2.2280 RMSE 3795.63 MAE 2571.03
# Step 7 | Valid MAPE 1.9742 RMSE 4577.12 MAE 2744.39 | Test MAPE 2.2311 RMSE 3795.66 MAE 2571.54
#
# Evaluating LAST_DAY...
# Best alignment: P=1, H=1, offset=12, MSE=0.00
# Step 1 | Valid MAPE 0.9142 RMSE 5790.20 MAE 2199.69 | Test MAPE 1.0149 RMSE 4480.64 MAE 1530.27
# Step 2 | Valid MAPE 0.9073 RMSE 5899.41 MAE 2373.78 | Test MAPE 0.9662 RMSE 4580.82 MAE 1594.86
# Step 3 | Valid MAPE 0.9834 RMSE 5356.37 MAE 2321.04 | Test MAPE 1.0130 RMSE 4476.72 MAE 1598.71
# Step 4 | Valid MAPE 0.9688 RMSE 5349.84 MAE 2333.66 | Test MAPE 1.0155 RMSE 4486.12 MAE 1596.00
# Step 5 | Valid MAPE 0.9022 RMSE 5919.50 MAE 2393.80 | Test MAPE 0.9909 RMSE 4537.15 MAE 1577.98
# Step 6 | Valid MAPE 0.8856 RMSE 5597.63 MAE 2130.28 | Test MAPE 0.9546 RMSE 4469.88 MAE 1507.35
# Step 7 | Valid MAPE 0.4768 RMSE 2549.18 MAE 694.79 | Test MAPE 0.4254 RMSE 2174.01 MAE 458.15
#
# Evaluating MOVING_AVERAGE...
# Best alignment: P=1, H=1, offset=12, MSE=0.00
# Step 1 | Valid MAPE 0.8451 RMSE 3830.96 MAE 1751.01 | Test MAPE 0.9093 RMSE 3089.70 MAE 1279.11
# Step 2 | Valid MAPE 0.8496 RMSE 3810.21 MAE 1748.43 | Test MAPE 0.9071 RMSE 3078.83 MAE 1270.16
# Step 3 | Valid MAPE 0.8490 RMSE 3803.45 MAE 1743.85 | Test MAPE 0.9062 RMSE 3090.44 MAE 1271.40
# Step 4 | Valid MAPE 0.8490 RMSE 3807.39 MAE 1744.34 | Test MAPE 0.9067 RMSE 3106.34 MAE 1274.76
# Step 5 | Valid MAPE 0.8490 RMSE 3817.18 MAE 1748.00 | Test MAPE 0.9038 RMSE 3125.29 MAE 1281.89
# Step 6 | Valid MAPE 0.8480 RMSE 3789.12 MAE 1736.60 | Test MAPE 0.9042 RMSE 3144.24 MAE 1289.30
# Step 7 | Valid MAPE 0.8495 RMSE 3750.97 MAE 1726.54 | Test MAPE 0.9030 RMSE 3165.23 MAE 1299.47

# %%
# Plot predictions for each method in a 2x2 grid (step 1/7, location 1/2)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load original raw data for baseline
valid_raw = pd.read_csv('/shares/mxq6904/yilongchen/baselines_imputation/MTGNN/raw/confirmed_state_valid.csv', header=None).iloc[1:].values
test_raw  = pd.read_csv('/shares/mxq6904/yilongchen/baselines_imputation/MTGNN/raw/confirmed_state_test.csv', header=None).iloc[1:].values

methods = ['stemgnn_r','stemgnn', 'stemgnn_w', 'mtgnn', 'mtgnn_w',  'last_day', 'moving_average']

for method in methods:
    fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True)
    axes = axes.flatten()
    idx = 0
    for step in [1, 7]:
        try:
            if method == 'stemgnn':
                predict_train = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state/train/val_step_{step}_predictions.csv', delimiter=',')
                target_train = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state/train/val_step_{step}_ground_truth.csv', delimiter=',')
                predict_test = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state/test/test_step_{step}_predictions.csv', delimiter=',')
                target_test = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state/test/test_step_{step}_ground_truth.csv', delimiter=',')
            elif method == 'stemgnn_w':
                predict_train = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state_w/train/val_step_{step}_predictions.csv', delimiter=',')
                target_train = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state_w/train/val_step_{step}_ground_truth.csv', delimiter=',')
                predict_test = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state_w/test/test_step_{step}_predictions.csv', delimiter=',')
                target_test = np.loadtxt(f'../../baselines_imputation/StemGNN/output/confirmed_state_w/test/test_step_{step}_ground_truth.csv', delimiter=',')
            elif method == 'stemgnn_r':
                # /shares/mxq6904/yilongchen/STAT-461-Group-Project/StemGNN_modified_data
                # /shares/mxq6904/yilongchen/STAT-461-Group-Project/StemGNN_modified_data/daily/confirmed_state/test/predict_step_2.csv
                predict_train = np.loadtxt(f'../StemGNN_modified_data/daily/confirmed_state/train/predict_step_{step-1}.csv', delimiter=',')
                target_train = np.loadtxt(f'../StemGNN_modified_data/daily/confirmed_state/train/target_step_{step-1}.csv', delimiter=',')
                predict_test = np.loadtxt(f'../StemGNN_modified_data/daily/confirmed_state/test/predict_step_{step-1}.csv', delimiter=',')
                target_test = np.loadtxt(f'../StemGNN_modified_data/daily/confirmed_state/test/target_step_{step-1}.csv', delimiter=',')
            elif method == 'mtgnn':
                predict_train = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily/val_step_{step}_predictions.csv', delimiter=',')
                target_train = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily/val_step_{step}_ground_truth.csv', delimiter=',')
                predict_test = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily/test_step_{step}_predictions.csv', delimiter=',')
                target_test = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily/test_step_{step}_ground_truth.csv', delimiter=',')
            elif method == 'mtgnn_w':
                predict_train = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily_W/val_step_{step}_predictions.csv', delimiter=',')
                target_train = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily_W/val_step_{step}_ground_truth.csv', delimiter=',')
                predict_test = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily_W/test_step_{step}_predictions.csv', delimiter=',')
                target_test = np.loadtxt(f'../../baselines_imputation/MTGNN/predictions/daily_W/test_step_{step}_ground_truth.csv', delimiter=',')
            elif method == 'last_day':
                # Baseline: use k days ago as prediction
                predict_train = valid_raw[:-step]  # Use t-step to predict t
                target_train = valid_raw[step:]    # Target is t
                min_len_train = min(len(predict_train), len(target_train))
                predict_train = predict_train[:min_len_train]
                target_train = target_train[:min_len_train]
                
                predict_test = test_raw[:-step]
                target_test = test_raw[step:]
                min_len_test = min(len(predict_test), len(target_test))
                predict_test = predict_test[:min_len_test]
                target_test = target_test[:min_len_test]
            elif method == 'moving_average':
                predict_train = np.zeros((len(valid_raw)-step, valid_raw.shape[1]))
                for i in range(len(predict_train)):
                    start = max(0, step + i - 7)
                    end = step + i
                    predict_train[i] = np.mean(valid_raw[start:end], axis=0)
                target_train = valid_raw[step:]
                min_len_train = min(len(predict_train), len(target_train))
                predict_train = predict_train[:min_len_train]
                target_train = target_train[:min_len_train]
                
                predict_test = np.zeros((len(test_raw)-step, test_raw.shape[1]))
                for i in range(len(predict_test)):
                    start = max(0, step + i - 7)
                    end = step + i
                    predict_test[i] = np.mean(test_raw[start:end], axis=0)
                target_test = test_raw[step:]
                min_len_test = min(len(predict_test), len(target_test))
                predict_test = predict_test[:min_len_test]
                target_test = target_test[:min_len_test]

            for loc in range(2):
                ax = axes[idx]
                # Plot train data
                ax.plot(range(len(target_train)), target_train[:, loc], label='Train Target', linewidth=1, color='skyblue')
                ax.plot(range(len(predict_train)), predict_train[:, loc], label='Train Predict', linewidth=1, linestyle='--', color='skyblue')
                # Plot test data
                start_test = len(target_train)
                ax.plot(range(start_test, start_test + len(target_test)), target_test[:, loc], label='Test Target', linewidth=1, color='lightcoral')
                ax.plot(range(start_test, start_test + len(predict_test)), predict_test[:, loc], label='Test Predict', linewidth=1, linestyle='--', color='lightcoral')
                ax.set_title(f'Step {step} Location {loc+1}')
                ax.legend()
                idx += 1

        except Exception as e:
            print(f"Error plotting {method} step {step}: {e}. Skipping.")
            idx += 2  # Skip both locations for this step

    fig.suptitle(f'Prediction vs Target ({method.upper()})', y=1.02, fontsize=16)
    plt.tight_layout()
    plt.show()
